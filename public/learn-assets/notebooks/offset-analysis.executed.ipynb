# %% [markdown]
# # Offset-adjusted measurements
# One row is one measurement; units are milliseconds.

# %%
values = [10, 20, 30]
offset = 2

# %%
adjusted = [x - offset for x in values]
mean = sum(adjusted) / len(adjusted)

# %%
assert len(adjusted) == 3
assert mean == 18.0
print(mean)
# Out:
# 18.0
